# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.preprocessing  import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt
x=np.arange(1,15)
X=x[:,np.newaxis]
y=np.log(x**2)+np.sqrt(x)
model=Ridge(alpha=0.05,normalize=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.5)
model.fit(X_train,y_train)
print(y_test)
model.predict(X_test)
n=3
model2=make_pipeline(PolynomialFeatures(degree=2),Ridge())
model2.fit(X_train,y_train)
b=model2.predict(X_test)
print(model2.score(X_test,y_test))
plt.plot(X_test,y_test,'r')
plt.plot(X_test,b,'b')
# Out:
# [6.53757161 6.03300868 4.77258872 2.80050792 8.73544999 7.39444915
#  8.11241534]
# 0.9865107594159706
# c:\python35-32\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
model3=KNeighborsRegressor(n_neighbors=2)
model3.fit(X_train,y_train)
model3.predict(X)
model3.score(X_test,y_test)
# Out:
# 0.9797085633293723
