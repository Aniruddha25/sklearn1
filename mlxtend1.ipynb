# %%
from sklearn.neighbors import KNeighborsRegressor
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
from sklearn.datasets import load_boston
from sklearn.linear_model import Ridge
from yellowbrick.features import RFECV
from sklearn.ensemble import GradientBoostingRegressor
boston = load_boston()
X, y = boston['data'], boston['target']
model=Ridge()

viz = RFECV(model)#Recursive feature elimination with cross-validation -to find optimal no. of features
viz.fit(X, y)
print("Optimal no. of features")
print(viz.n_features_)
k=int(viz.n_features_)




efs1 = EFS(model, 
           min_features=1,
           max_features=5,
           scoring='r2',
           cv=10)

efs1 = efs1.fit(X, y)

print('Best accuracy score: %.2f' % efs1.best_score_)
print('Best subset (indices):', efs1.best_idx_)
# Out:
# Optimal no. of features
# 7
# Features: 2379/2379
# Best accuracy score: 0.27
# Best subset (indices): (3, 5, 10, 11, 12)
